# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
eplData = pd.read_csv("E:\PycharmProjects\premierLeague\premier-league\stats.csv")

# %%
eplData.shape
# Out:
# (240, 42)

# %%
eplData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 42 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   team                  240 non-null    object
#  1   wins                  240 non-null    float64
#  2   losses                240 non-null    float64
#  3   goals                 240 non-null    float64
#  4   total_yel_card        240 non-null    float64
#  5   total_red_card        240 non-null    float64
#  6   total_scoring_att     240 non-null    float64
#  7   ontarget_scoring_att  240 non-null    float64
#  8   hit_woodwork          240 non-null    float64
#  9   att_hd_goal           240 non-null    float64
#  10  att_pen_goal          240 non-null    float64
#  11  att_freekick_goal     240 non-null    float64
#  12  att_ibox_goal         240 non-null    float64
#  13  att_obox_goal         240 non-null    float64
# ...

# %%
eplData.describe()
# Out:
#              wins      losses       goals  total_yel_card  total_red_card  \
# count  240.000000  240.000000  240.000000      240.000000      240.000000
# mean    14.150000   14.150000   51.062500       61.079167        2.862500
# std      6.022482    5.596846   16.203474       10.078249        1.802442
# min      1.000000    2.000000   20.000000       38.000000        0.000000
# 25%     10.000000   10.000000   40.000000       54.000000        1.000000
# 50%     12.000000   15.000000   47.000000       60.500000        3.000000
# 75%     18.000000   19.000000   61.000000       67.000000        4.000000
# max     32.000000   29.000000  106.000000       94.000000        9.000000
#
#        total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  \
# count         240.000000            240.000000    240.000000   240.000000
# mean          514.241667            168.116667     12.283333     9.016667
# std            95.979164             38.748882      4.820950     3.659077
# ...

# %%
plt.scatter(eplData.big_chance_missed, eplData.goal_fastbreak, alpha=0.1)
plt.title("Big chence misssed, fastbreak")
# Out:
# Text(0.5, 1.0, 'Big chence misssed, fastbreak')

# %%
eplData.hist(bins=100, figsize=(9,7), grid=False);

# %%
g = sns.FacetGrid(eplData, col="wins", row="losses", margin_titles=True)
g.map(plt.hist, "team", color="cyan")

# %%
g = g = sns.FacetGrid(eplData, hue="ontarget_scoring_att", col="clean_sheet", margin_titles=True,
                  palette={1: "seagreen", 0: "gray"})
g=g.map(plt.scatter, "wins", "loses", edgecolor="w").add_legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-a64c2bbd3d07> in <module>
#       1 g = g = sns.FacetGrid(eplData, hue="ontarget_scoring_att", col="clean_sheet", margin_titles=True,
# ----> 2                   palette={1: "seagreen", 0: "gray"})
#       3 g=g.map(plt.scatter, "wins", "loses", edgecolor="w").add_legend()
#
# D:\ProgramData\anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     250             hue_names = utils.categorical_order(data[hue], hue_order)
#     251
# --> 252         colors = self._get_palette(data, hue, hue_order, palette)
#     253
#     254         # Set up the lists of names for the row and column facet variables
# ...

# %%
ax = sns.boxplot(x="team", y="total_pass", data=eplData)
ax = sns.stripplot(x="team", y="total_pass", data=eplData,
                   jitter=True, edgecolor="gray")

# %%
g = sns.FacetGrid(eplData, hue="team", col="goals", margin_titles=True,
                  palette="Set1", hue_kws=dict(marker=["^", "v"]))
g.map(plt.scatter, "own_goals", "goals_conceded", edcolor="w").add_legend()
plt.subplots_adjust(top=0.8)
g.fig.suptitle('Team by goals, Own and goals conceded')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-49dd825ff305> in <module>
#       1 g = sns.FacetGrid(eplData, hue="team", col="goals", margin_titles=True,
#       2                   palette="Set1", hue_kws=dict(marker=["^", "v"]))
# ----> 3 g.map(plt.scatter, "own_goals", "goals_conceded", edcolor="w").add_legend()
#       4 plt.subplots_adjust(top=0.8)
#       5 g.fig.suptitle('Team by goals, Own and goals conceded')
#
# D:\ProgramData\anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     748             # Insert the other hue aesthetics if appropriate
#     749             for kw, val_list in self.hue_kws.items():
# --> 750                 kwargs[kw] = val_list[hue_k]
#     751
#     752             # Insert a label in the keyword arguments for the legend
#
# IndexError: list index out of range
